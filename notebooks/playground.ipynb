# %%
import pandas as pd

df = pd.read_csv('simulation_results.metrics')
df
# Out:
#                                 Metric CS1_FLAT_50EVs_15km_SOCmin40%  \
# 0                          Tariff type                          flat
# 1                        Number of EVs                            50
# 2         Average travel distance (km)                         15 km
# 3                      Minimum SOC (%)                           40%
# 4                 Number of households                           100
# 5                        Number of CPs                            50
# 6              Max charging power (kW)                       1.30 kW
# 7                       Total cost ($)                    $30,544.63
# 8    Investment & maintenance cost ($)                    $10,383.56
# 9        Total household load cost ($)                    $19,669.42
# 10          Total EV charging cost ($)                       $489.02
# 11                Grid import cost ($)                    $20,158.45
# 12                     Other costs ($)                         $2.62
# ...
