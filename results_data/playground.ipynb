# %%
import pandas as pd

df = pd.read_csv('model_results.csv')
df
# Out:
#                                 Metric CS1_flat_50EVs_30km_SOCmin30%  \
# 0                          Tariff type                          flat
# 1                        Number of EVs                            50
# 2         Average travel distance (km)                         30 km
# 3                      Minimum SOC (%)                           30%
# 4                 Number of households                           100
# 5                        Number of CPs                            50
# 6              Max charging power (kW)                       2.40 kW
# 7                       Total cost ($)                    $30,922.35
# 8    Investment & maintenance cost ($)                    $10,383.56
# 9        Total household load cost ($)                    $19,669.42
# 10          Total EV charging cost ($)                       $866.58
# 11                Grid import cost ($)                    $20,536.00
# 12                     Other costs ($)                         $2.79
# ...
