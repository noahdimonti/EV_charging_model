# %%
import pandas as pd

df = pd.read_csv('model_results.csv')
df
# Out:
#                                 Metric CS1_flat_100EVs_30km_SOCmin30%  \
# 0                          Tariff type                           flat
# 1                        Number of EVs                            100
# 2         Average travel distance (km)                          30 km
# 3                      Minimum SOC (%)                            30%
# 4                 Number of households                            100
# 5                        Number of CPs                            100
# 6              Max charging power (kW)                        2.40 kW
# 7                       Total cost ($)                     $42,627.17
# 8    Investment & maintenance cost ($)                     $20,767.12
# 9        Total household load cost ($)                     $19,669.42
# 10          Total EV charging cost ($)                      $2,031.90
# 11                Grid import cost ($)                     $21,701.32
# ...
