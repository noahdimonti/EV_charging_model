# %%
import pandas as pd

df = pd.read_csv('model_results.csv')
df
# Out:
#                                 Metric CS1_flat_100EVs_35km_SOCmin90%  \
# 0                          Tariff type                           flat
# 1                        Number of EVs                            100
# 2         Average travel distance (km)                          35 km
# 3                      Minimum SOC (%)                            90%
# 4                 Number of households                            100
# 5                        Number of CPs                            100
# 6              Max charging power (kW)                        7.20 kW
# 7                       Total cost ($)                    $173,011.99
# 8    Investment & maintenance cost ($)                    $150,767.12
# 9        Total household load cost ($)                     $19,669.42
# 10          Total EV charging cost ($)                      $2,570.70
# 11                Grid import cost ($)                     $22,240.13
# ...
