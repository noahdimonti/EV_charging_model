# %%
import numpy as np
import pandas as pd

df_cost = pd.read_csv('df_cost.csv')
df_power = pd.read_csv('df_power.csv')

# %%
df_cost
# Out:
#    Unnamed: 0 Tariff type  Total optimal cost ($)  \
# 0           0        flat            31446.033260
# 1           1         tou            29806.550818
#
#    Investment & maintenance cost ($)  Total household load cost ($)  \
# 0                       10383.561644                   19669.422165
# 1                       10383.561644                   18898.202035
#
#    Total EV charging cost ($)  Grid import cost ($)  Other costs ($)  \
# 0                 1234.595055          20904.017220         1.418580
# 1                  364.479919          19262.681954         3.271404
#
#    Average EV charging cost ($)
# 0                     24.691901
# 1                      7.289598

# %%
df_power
# Out:
#    Unnamed: 0                   power_information  CS1_flat_tariff_20_EVs  \
# 0           0                Number of households              100.000000
# 1           1                       Number of EVs               20.000000
# 2           2                       Number of CPs               20.000000
# 3           3             Max charging power (kW)                2.400000
# 4           4                   Peak EV load (kW)                5.855623
# 5           5              Peak total demand (kW)              157.035817
# 6           6               Peak grid import (kW)              157.035817
# 7           7             Average daily peak (kW)              137.019212
# 8           8  Peak-to-average power ratio (PAPR)                1.980682
#
#    CS1_flat_tariff_40_EVs  CS1_flat_tariff_50_EVs  CS1_flat_tariff_60_EVs  \
# 0              100.000000              100.000000              100.000000
# 1               40.000000               50.000000               60.000000
# ...
